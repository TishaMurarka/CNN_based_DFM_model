# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/pharma-sales-data/salesdaily.csv
# /kaggle/input/pharma-sales-data/salesweekly.csv
# /kaggle/input/pharma-sales-data/salesmonthly.csv
# /kaggle/input/pharma-sales-data/saleshourly.csv

# %% [markdown]
# ## **Import Libraries**

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# from keras.models import Sequential
# from keras.layers import Conv2D, Dropout, BatchNormalization, Flatten, Dense, MaxPooling2D
# from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_absolute_error, confusion_matrix, classification_report
from sklearn.metrics import mean_squared_error, roc_curve, auc, r2_score, roc_auc_score
from sklearn.model_selection import train_test_split

from datetime import datetime
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2024-04-11 18:05:36.635583: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-11 18:05:36.635743: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-11 18:05:36.816061: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
salesdaily=pd.read_csv('/kaggle/input/pharma-sales-data/salesdaily.csv')
saleshourly=pd.read_csv('/kaggle/input/pharma-sales-data/saleshourly.csv')
salesmonthly=pd.read_csv('/kaggle/input/pharma-sales-data/salesmonthly.csv')
salesweekly=pd.read_csv('/kaggle/input/pharma-sales-data/salesweekly.csv')

# %%
salesdaily.head()
# Out:
#       datum  M01AB  M01AE  N02BA  N02BE  N05B  N05C   R03  R06  Year  Month  \
# 0  1/2/2014    0.0   3.67    3.4  32.40   7.0   0.0   0.0  2.0  2014      1
# 1  1/3/2014    8.0   4.00    4.4  50.60  16.0   0.0  20.0  4.0  2014      1
# 2  1/4/2014    2.0   1.00    6.5  61.85  10.0   0.0   9.0  1.0  2014      1
# 3  1/5/2014    4.0   3.00    7.0  41.10   8.0   0.0   3.0  0.0  2014      1
# 4  1/6/2014    5.0   1.00    4.5  21.70  16.0   2.0   6.0  2.0  2014      1
#
#    Hour Weekday Name
# 0   248     Thursday
# 1   276       Friday
# 2   276     Saturday
# 3   276       Sunday
# 4   276       Monday

# %%
saleshourly.head()
# Out:
#             datum  M01AB  M01AE  N02BA  N02BE  N05B  N05C  R03  R06  Year  \
# 0   1/2/2014 8:00    0.0   0.67    0.4    2.0   0.0   0.0  0.0  1.0  2014
# 1   1/2/2014 9:00    0.0   0.00    1.0    0.0   2.0   0.0  0.0  0.0  2014
# 2  1/2/2014 10:00    0.0   0.00    0.0    3.0   2.0   0.0  0.0  0.0  2014
# 3  1/2/2014 11:00    0.0   0.00    0.0    2.0   1.0   0.0  0.0  0.0  2014
# 4  1/2/2014 12:00    0.0   2.00    0.0    5.0   2.0   0.0  0.0  0.0  2014
#
#    Month  Hour Weekday Name
# 0      1     8     Thursday
# 1      1     9     Thursday
# 2      1    10     Thursday
# 3      1    11     Thursday
# 4      1    12     Thursday

# %%
salesweekly.head()
# Out:
#        datum  M01AB  M01AE  N02BA   N02BE  N05B  N05C   R03   R06
# 0   1/5/2014  14.00  11.67   21.3  185.95  41.0   0.0  32.0   7.0
# 1  1/12/2014  29.33  12.68   37.9  190.70  88.0   5.0  21.0   7.2
# 2  1/19/2014  30.67  26.34   45.9  218.40  80.0   8.0  29.0  12.0
# 3  1/26/2014  34.00  32.37   31.5  179.60  80.0   8.0  23.0  10.0
# 4   2/2/2014  31.02  23.35   20.7  159.88  84.0  12.0  29.0  12.0

# %%
salesmonthly.head()
# Out:
#         datum   M01AB    M01AE    N02BA     N02BE   N05B  N05C    R03    R06
# 0  2014-01-31  127.69   99.090  152.100   878.030  354.0  50.0  112.0   48.2
# 1  2014-02-28  133.32  126.050  177.000  1001.900  347.0  31.0  122.0   36.2
# 2  2014-03-31  137.44   92.950  147.655   779.275  232.0  20.0  112.0   85.4
# 3  2014-04-30  113.10   89.475  130.900   698.500  209.0  18.0   97.0   73.7
# 4  2014-05-31  101.79  119.933  132.100   628.780  270.0  23.0  107.0  123.7

# %%
fig, axes = plt.subplots(8, 1, figsize=(10, 30), sharex=True)
for name, ax in zip(['M01AB','M01AE','N02BA','N02BE', 'N05B','N05C','R03','R06'], axes):
    sns.boxplot(data=salesdaily, x='Month', y=name, ax=ax)

# %% [markdown]
# ## **Load Data**

# %%
data = pd.read_csv('/kaggle/input/pharma-sales-data/salesmonthly.csv')

# %% [markdown]
# ## **Data Preprocessing**

# %%
# Check for missing values
missing_values = data.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  datum    0
# M01AB    0
# M01AE    0
# N02BA    0
# N02BE    0
# N05B     0
# N05C     0
# R03      0
# R06      0
# dtype: int64

# %%
atc_categories = ['M01AB','M01AE','N02BA','N02BE', 'N05B','N05C','R03','R06']
category_sales = {}
for category in atc_categories:
    category_sales[category] = data.groupby(category).sum()

# %%
data.head()
# Out:
#         datum   M01AB    M01AE    N02BA     N02BE   N05B  N05C    R03    R06
# 0  2014-01-31  127.69   99.090  152.100   878.030  354.0  50.0  112.0   48.2
# 1  2014-02-28  133.32  126.050  177.000  1001.900  347.0  31.0  122.0   36.2
# 2  2014-03-31  137.44   92.950  147.655   779.275  232.0  20.0  112.0   85.4
# 3  2014-04-30  113.10   89.475  130.900   698.500  209.0  18.0   97.0   73.7
# 4  2014-05-31  101.79  119.933  132.100   628.780  270.0  23.0  107.0  123.7

# %%
data.shape
# Out:
# (70, 9)

# %%
# Assuming 'salesmonthly' is your DataFrame and 'datum' column contains dates as strings
salesmonthly['datum'] = pd.to_datetime(salesmonthly['datum'])

# %%
salesmonthly
# Out:
#         datum   M01AB    M01AE    N02BA     N02BE   N05B  N05C    R03     R06
# 0  2014-01-31  127.69   99.090  152.100   878.030  354.0  50.0  112.0   48.20
# 1  2014-02-28  133.32  126.050  177.000  1001.900  347.0  31.0  122.0   36.20
# 2  2014-03-31  137.44   92.950  147.655   779.275  232.0  20.0  112.0   85.40
# 3  2014-04-30  113.10   89.475  130.900   698.500  209.0  18.0   97.0   73.70
# 4  2014-05-31  101.79  119.933  132.100   628.780  270.0  23.0  107.0  123.70
# ..        ...     ...      ...      ...       ...    ...   ...    ...     ...
# 65 2019-06-30  151.54  101.627  103.200   610.000  193.0  25.0  142.0  156.04
# 66 2019-07-31  181.00  103.541   92.800   649.800  250.6  20.0  115.0  105.20
# 67 2019-08-31  181.91   88.269   84.200   518.100  237.0  26.0  145.0   97.30
# 68 2019-09-30  161.07  111.437   93.500   984.480  227.8  16.0  161.0  109.10
# 69 2019-10-31   44.37   37.300   20.650   295.150   86.0   7.0   37.0   11.13
#
# [70 rows x 9 columns]

# %%
print(salesmonthly['datum'].min())
print(salesmonthly['datum'].max())
# Out:
# 2014-01-31 00:00:00
# 2019-10-31 00:00:00

# %%
# Reshape the dataframe
salesmonthly_new = salesmonthly.melt(id_vars=['datum'],
             var_name='Drug',
             value_name='Quantity')

# Print the updated dataframe
salesmonthly_new
# Out:
#          datum   Drug  Quantity
# 0   2014-01-31  M01AB    127.69
# 1   2014-02-28  M01AB    133.32
# 2   2014-03-31  M01AB    137.44
# 3   2014-04-30  M01AB    113.10
# 4   2014-05-31  M01AB    101.79
# ..         ...    ...       ...
# 555 2019-06-30    R06    156.04
# 556 2019-07-31    R06    105.20
# 557 2019-08-31    R06     97.30
# 558 2019-09-30    R06    109.10
# 559 2019-10-31    R06     11.13
#
# [560 rows x 3 columns]

# %%
import plotly.express as px

# Plot the graph on drug basis
fig = px.line(salesmonthly_new, x='datum', y='Quantity', color='Drug', 
              title='Monthly Sales Quantity of Drugs', labels={'datum': 'Date', 'Quantity': 'Sales Quantity'})

# Show the plot
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="1dd97e9d-be7f-4578-ab6f-66d6872e5209" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1dd97e9d-be7f-4578-ab6f-66d6872e5209")) {                    Plotly.newPlot(                        "1dd97e9d-be7f-4578-ab6f-66d6872e5209",                        [{"hovertemplate":"Drug=M01AB\u003cbr\u003eDate=%{x}\u003cbr\u003eSales Quantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M01AB","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"M01AB","orientation":"v","showlegend":true,"x":["2014-01-31T00:00:00","2014-02-28T00:00:00","2014-03-31T00:00:00","2014-04-30T00:00:00","2014-05-31T00:00:00","2014-06-30T00:00:00","2014-07-31T00:00:00","2014-08-31T00:00:00","2014-09-30T00:00:00","2014-10-31T00:00:00","2014-11-30T00:00:00","2014-12-31T00:00:00","2015-01-31T00:00:00","2015-02-28T00:00:00","2015-03-31T00:00:00","2015-04-30T00:00:00","2015-05-31T00:00:00","2015-06-30T00:00:00","2015-07-31T00:00:00","2015-08-31T00:00:00","2015-09-30T00:00:00","2015-10-31T00:00:00","2015-11-30T00:00:00","2015-12-31T00:00:00","2016-01-31T00:00:00","2016-02-29T00:00:00","2016-03-31T00:00:00","2016-04-30T00:00:00","2016-05-31T00:00:00","2016-06-30T00:00:00","2016-07-31T00:00:00","2016-08-31T00:00:00","2016-09-30T00:00:00","2016-10-31T00:00:00","2016-11-30T00:00:00","2016-12-31T00:00:00","2017-01-31T00:00:00","2017-02-28T00:00:00","2017-03-31T00:00:00","2017-04-30T00:00:00","2017-05-31T00:00:00","2017-06-30T00:00:00","2017-07-31T00:00:00","2017-08-31T00:00:00","2017-09-30T00:00:00","2017-10-31T00:00:00","2017-11-30T00:00:00","2017-12-31T00:00:00","2018-01-31T00:00:00","2018-02-28T00:00:00","2018-03-31T00:00:00","2018-04-30T00:00:00","2018-05-31T00:00:00","2018-06-30T00:00:00","2018-07-31T00:00:00","2018-08-31T00:00:00","2018-09-30T00:00:00","2018-10-31T00:00:00","2018-11-30T00:00:00","2018-12-31T00:00:00","2019-01-31T00:00:00","2019-02-28T00:00:00","2019-03-31T00:00:00","2019-04-30T00:00:00","2019-05-31T00:00:00","2019-06-30T00:00:00","2019-07-31T00:00:00","2019-08-31T00:00:00","2019-09-30T00:00:00","2019-10-31T00:00:00"],"xaxis":"x","y":[127.69,133.32,137.44000000000003,113.10000000000004,101.79000000000003,112.07000000000002,117.06000000000002,134.79000000000005,108.78000000000004,154.75000000000003,138.08000000000004,131.90000000000003,135.91000000000005,115.71,156.04000000000005,154.5,160.02,151.87000000000003,175.61000000000004,181.69000000000003,166.22000000000008,195.81000000000012,152.78000000000006,159.46000000000004,171.65000000000006,173.81000000000003,156.64000000000004,166.6100000000001,167.36000000000007,169.67000000000002,203.97000000000017,211.13000000000017,172.96000000000004,186.7600000000001,175.18000000000012,169.32000000000002,0.0,139.69000000000003,162.85000000000002,155.61000000000004,143.66,122.33,159.67,170.14999999999998,138.33,137.64,163.85000000000005,160.01000000000002,132.28,128.36,146.16,170.02000000000007,160.52000000000004,141.18,150.18,140.00000000000003,153.52,144.71000000000004,172.29000000000005,147.71000000000004,179.70000000000007,133.73000000000002,154.52000000000004,161.39000000000004,168.04000000000005,151.5400000000001,181.0,181.91000000000008,161.07000000000005,44.370000000000005],"yaxis":"y","type":"scatter"},{"hovertemplate":"Drug=M01AE\u003cbr\u003eDate=%{x}\u003cbr\u003eSales Quantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M01AE","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"M01AE","orientation":"v","showlegend":true,"x":["2014-01-31T00:00:00","2014-02-28T00:00:00","2014-03-31T00:00:00","2014-04-30T00:00:00","2014-05-31T00:00:00","2014-06-30T00:00:00","2014-07-31T00:00:00","2014-08-31T00:00:00","2014-09-30T00:00: ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
# salesmonthly_new['datum'] = le.fit_transform(salesmonthly_new['datum'])
salesmonthly_new['Drug'] = le.fit_transform(salesmonthly_new['Drug'])
salesmonthly_new
# Out:
#          datum  Drug  Quantity
# 0   2014-01-31     0    127.69
# 1   2014-02-28     0    133.32
# 2   2014-03-31     0    137.44
# 3   2014-04-30     0    113.10
# 4   2014-05-31     0    101.79
# ..         ...   ...       ...
# 555 2019-06-30     7    156.04
# 556 2019-07-31     7    105.20
# 557 2019-08-31     7     97.30
# 558 2019-09-30     7    109.10
# 559 2019-10-31     7     11.13
#
# [560 rows x 3 columns]

# %%
# Create a new index column
salesmonthly_new['Index'] = range(len(salesmonthly_new))

# Set 'Index' as the index
salesmonthly_new.set_index('Index', inplace=True)

# %%
salesmonthly_new
# Out:
#            datum  Drug  Quantity
# Index
# 0     2014-01-31     0    127.69
# 1     2014-02-28     0    133.32
# 2     2014-03-31     0    137.44
# 3     2014-04-30     0    113.10
# 4     2014-05-31     0    101.79
# ...          ...   ...       ...
# 555   2019-06-30     7    156.04
# 556   2019-07-31     7    105.20
# 557   2019-08-31     7     97.30
# 558   2019-09-30     7    109.10
# 559   2019-10-31     7     11.13
#
# [560 rows x 3 columns]

# %% [markdown]
# ## **Model Fitting**

# %%
# Function to prepare data
def prepare_data(time_data, n_features):
    X, y = [], []
    for i in range(len(time_data)):
        end_ix = i + n_features
        if end_ix > len(time_data) - 1:
            break
        X.append(time_data[i:end_ix])
        y.append(time_data[end_ix])
    return np.array(X), np.array(y)

# %%
# Splitting data into train and test sets
split_index = 550
train = salesmonthly_new.iloc[:split_index]
test = salesmonthly_new.iloc[split_index:]

# %%
# Extract features and target
X_train = train.drop(['datum'], axis=1).values
y_train = train['Quantity'].values
X_test = test.drop(['datum'], axis=1).values
y_test = test['Quantity'].values

# %%
# Standardize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Normalize target variable
scaler_y = StandardScaler()
y_train = scaler_y.fit_transform(y_train.reshape(-1, 1)).flatten()
y_test = scaler_y.transform(y_test.reshape(-1, 1)).flatten()

# %%
# Split the data
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=42)

# %%
# Define the LSTM model architecture
def create_lstm_model(input_shape, n_units=256, n_layers=3, dropout_rate=0.3):
    model = Sequential()
    for i in range(n_layers):
        model.add(LSTM(units=n_units, activation='relu', return_sequences=True if i < n_layers - 1 else False,
                       input_shape=input_shape))
        model.add(BatchNormalization())
        model.add(Dropout(dropout_rate))
    model.add(Dense(1))  # Output layer
    return model

# Create the LSTM model
n_features = X_train.shape[1]
input_shape = (n_features, 1)
model = create_lstm_model(input_shape)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 2, 256)         │       264,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 2, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 2, 256)         │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 2, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 2, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 256)            │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,318,145 (5.03 MB)
#  Trainable params: 1,316,609 (5.02 MB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
# Compile the model
model.compile(optimizer='adam', loss='mae')

# Early stopping and learning rate reduction to prevent overfitting
early_stopping = EarlyStopping(patience=20, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(factor=0.1, patience=10, min_lr=1e-6)

# Train the model
history = model.fit(X_train, y_train, epochs=200, batch_size=64, validation_data=(X_val, y_val),
                    callbacks=[early_stopping, reduce_lr])

# Evaluate the model
train_loss = model.evaluate(X_train, y_train, verbose=0)
val_loss = model.evaluate(X_val, y_val, verbose=0)
train_mae = np.mean(np.abs(model.predict(X_train) - y_train))
val_mae = np.mean(np.abs(model.predict(X_val) - y_val))

print('Train Loss:', train_loss)
print('Validation Loss:', val_loss)
print('Train MAE:', train_mae)
print('Validation MAE:', val_mae)

# Plot training and validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 158ms/step - loss: 1.7056 - val_loss: 0.6001 - learning_rate: 0.0010
# Epoch 2/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.3241 - val_loss: 0.5789 - learning_rate: 0.0010
# Epoch 3/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.9121 - val_loss: 0.5807 - learning_rate: 0.0010
# Epoch 4/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.8788 - val_loss: 0.5679 - learning_rate: 0.0010
# Epoch 5/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.8382 - val_loss: 0.5510 - learning_rate: 0.0010
# Epoch 6/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.9016 - val_loss: 0.5375 - learning_rate: 0.0010
# Epoch 7/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.8598 - val_loss: 0.5292 - learning_rate: 0.0010
# Epoch 8/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.7755 - val_loss: 0.5255 - learning_rate: 0.0010
# Epoch 9/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.7262 - val_loss: 0.5235 - learning_rate: 0.0010
# Epoch 10/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.7141 - val_loss: 0.5207 - learning_rate: 0.0010
# Epoch 11/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.6810 - val_loss: 0.5267 - learning_rate: 0.0010
# Epoch 12/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.7408 - val_loss: 0.5334 - learning_rate: 0.0010
# Epoch 13/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.5768 - val_loss: 0.5303 - learning_rate: 0.0010
# Epoch 14/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.7131 - val_loss: 0.5088 - learning_rate: 0.0010
# Epoch 15/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.6478 - val_loss: 0.5019 - learning_rate: 0.0010
# Epoch 16/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.6378 - val_loss: 0.5084 - learning_rate: 0.0010
# Epoch 17/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.5710 - val_loss: 0.5166 - learning_rate: 0.0010
# Epoch 18/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.6054 - val_loss: 0.5031 - learning_rate: 0.0010
# Epoch 19/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.5534 - val_loss: 0.5026 - learning_rate: 0.0010
# Epoch 20/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.5181 - val_loss: 0.5051 - learning_rate: 0.0010
# Epoch 21/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.5173 - val_loss: 0.4933 - learning_rate: 0.0010
# Epoch 22/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.5853 - val_loss: 0.4889 - learning_rate: 0.0010
# Epoch 23/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.5706 - val_loss: 0.4939 - learning_rate: 0.0010
# Epoch 24/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.5565 - val_loss: 0.4908 - learning_rate: 0.0010
# Epoch 25/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.4868 - val_loss: 0.4932 - learning_rate: 0.0010
# Epoch 26/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.5132 - val_loss: 0.4911 - learning_rate: 0.0010
# Epoch 27/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.5671 - val_loss: 0.4917 - learning_rate: 0.0010
# Epoch 28/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.5000 - val_loss: 0.4876 - learning_rate: 0.0010
# Epoch 29/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.4532 - val_loss: 0.4852 - learning_rate: 0.0010
# Epoch 30/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.4777 - val_loss: 0.4864 - learning_rate: 0.0010
# Epoch 31/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.4778 - val_loss: 0.4910 - learning_rate: 0.0010
# Epoch 32/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.4457 - val_loss: 0.4860 - learning_rate: 0.0010
# Epoch 33/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.5142 - val_loss: 0.4837 - learning_rate: 0.0010
# Epoch 34/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.4159 - val_loss: 0.4836 - learning_rate: 0.0010
# Epoch 35/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.4464 - val_loss: 0.4833 - learning_rate: 0.0010
# Epoch 36/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.4208 - val_loss: 0.4828 - learning_rate: 0.0010
# Epoch 37/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.4753 - val_loss: 0.4843 - learning_rate: 0.0010
# Epoch 38/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.4014 - val_loss: 0.4837 - learning_rate: 0.0010
# Epoch 39/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.4271 - val_loss: 0.4824 - learning_rate: 0.0010
# Epoch 40/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.3776 - val_loss: 0.4808 - learning_rate: 0.0010
# Epoch 41/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.3790 - val_loss: 0.4809 - learning_rate: 0.0010
# Epoch 42/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.3517 - val_loss: 0.4793 - learning_rate: 0.0010
# Epoch 43/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.3561 - val_loss: 0.4791 - learning_rate: 0.0010
# Epoch 44/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.3344 - val_loss: 0.4802 - learning_rate: 0.0010
# Epoch 45/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.3832 - val_loss: 0.4780 - learning_rate: 0.0010
# Epoch 46/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.3181 - val_loss: 0.4782 - learning_rate: 0.0010
# Epoch 47/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.4003 - val_loss: 0.4768 - learning_rate: 0.0010
# Epoch 48/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.3251 - val_loss: 0.4759 - learning_rate: 0.0010
# Epoch 49/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.3029 - val_loss: 0.4731 - learning_rate: 0.0010
# Epoch 50/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.3425 - val_loss: 0.4727 - learning_rate: 0.0010
# Epoch 51/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3022 - val_loss: 0.4756 - learning_rate: 0.0010
# Epoch 52/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2871 - val_loss: 0.4686 - learning_rate: 0.0010
# Epoch 53/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.3256 - val_loss: 0.4690 - learning_rate: 0.0010
# Epoch 54/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3026 - val_loss: 0.4701 - learning_rate: 0.0010
# Epoch 55/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.3049 - val_loss: 0.4650 - learning_rate: 0.0010
# Epoch 56/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3156 - val_loss: 0.4617 - learning_rate: 0.0010
# Epoch 57/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.4086 - val_loss: 0.4610 - learning_rate: 0.0010
# Epoch 58/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.3468 - val_loss: 0.4592 - learning_rate: 0.0010
# Epoch 59/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.3036 - val_loss: 0.4575 - learning_rate: 0.0010
# Epoch 60/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.2632 - val_loss: 0.4628 - learning_rate: 0.0010
# Epoch 61/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2918 - val_loss: 0.4537 - learning_rate: 0.0010
# Epoch 62/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2566 - val_loss: 0.4470 - learning_rate: 0.0010
# Epoch 63/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.2643 - val_loss: 0.4458 - learning_rate: 0.0010
# Epoch 64/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2766 - val_loss: 0.4404 - learning_rate: 0.0010
# Epoch 65/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.3445 - val_loss: 0.4345 - learning_rate: 0.0010
# Epoch 66/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2423 - val_loss: 0.4333 - learning_rate: 0.0010
# Epoch 67/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2215 - val_loss: 0.4258 - learning_rate: 0.0010
# Epoch 68/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2497 - val_loss: 0.4168 - learning_rate: 0.0010
# Epoch 69/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.2568 - val_loss: 0.4119 - learning_rate: 0.0010
# Epoch 70/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2446 - val_loss: 0.4053 - learning_rate: 0.0010
# Epoch 71/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2741 - val_loss: 0.3970 - learning_rate: 0.0010
# Epoch 72/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2595 - val_loss: 0.3930 - learning_rate: 0.0010
# Epoch 73/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2458 - val_loss: 0.3855 - learning_rate: 0.0010
# Epoch 74/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.2374 - val_loss: 0.3829 - learning_rate: 0.0010
# Epoch 75/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2120 - val_loss: 0.3759 - learning_rate: 0.0010
# Epoch 76/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2133 - val_loss: 0.3635 - learning_rate: 0.0010
# Epoch 77/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.2225 - val_loss: 0.3632 - learning_rate: 0.0010
# Epoch 78/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.2386 - val_loss: 0.3476 - learning_rate: 0.0010
# Epoch 79/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2066 - val_loss: 0.3253 - learning_rate: 0.0010
# Epoch 80/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2450 - val_loss: 0.3277 - learning_rate: 0.0010
# Epoch 81/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2017 - val_loss: 0.3272 - learning_rate: 0.0010
# Epoch 82/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2453 - val_loss: 0.3225 - learning_rate: 0.0010
# Epoch 83/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2268 - val_loss: 0.3082 - learning_rate: 0.0010
# Epoch 84/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2580 - val_loss: 0.2910 - learning_rate: 0.0010
# Epoch 85/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1962 - val_loss: 0.2673 - learning_rate: 0.0010
# Epoch 86/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1937 - val_loss: 0.2967 - learning_rate: 0.0010
# Epoch 87/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2027 - val_loss: 0.2962 - learning_rate: 0.0010
# Epoch 88/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.2733 - val_loss: 0.2340 - learning_rate: 0.0010
# Epoch 89/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.2876 - val_loss: 0.2442 - learning_rate: 0.0010
# Epoch 90/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.1911 - val_loss: 0.2616 - learning_rate: 0.0010
# Epoch 91/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1977 - val_loss: 0.2369 - learning_rate: 0.0010
# Epoch 92/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.2410 - val_loss: 0.2180 - learning_rate: 0.0010
# Epoch 93/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.1956 - val_loss: 0.2215 - learning_rate: 0.0010
# Epoch 94/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.2003 - val_loss: 0.1752 - learning_rate: 0.0010
# Epoch 95/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1777 - val_loss: 0.2208 - learning_rate: 0.0010
# Epoch 96/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2504 - val_loss: 0.1874 - learning_rate: 0.0010
# Epoch 97/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2056 - val_loss: 0.1450 - learning_rate: 0.0010
# Epoch 98/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1994 - val_loss: 0.1814 - learning_rate: 0.0010
# Epoch 99/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.1899 - val_loss: 0.1977 - learning_rate: 0.0010
# Epoch 100/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.2007 - val_loss: 0.1316 - learning_rate: 0.0010
# Epoch 101/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3745 - val_loss: 0.1409 - learning_rate: 0.0010
# Epoch 102/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1536 - val_loss: 0.1208 - learning_rate: 0.0010
# Epoch 103/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.1563 - val_loss: 0.1602 - learning_rate: 0.0010
# Epoch 104/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3308 - val_loss: 0.1558 - learning_rate: 0.0010
# Epoch 105/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2129 - val_loss: 0.0955 - learning_rate: 0.0010
# Epoch 106/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1593 - val_loss: 0.1245 - learning_rate: 0.0010
# Epoch 107/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.1561 - val_loss: 0.1152 - learning_rate: 0.0010
# Epoch 108/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1761 - val_loss: 0.0751 - learning_rate: 0.0010
# Epoch 109/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2642 - val_loss: 0.0842 - learning_rate: 0.0010
# Epoch 110/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.1671 - val_loss: 0.1021 - learning_rate: 0.0010
# Epoch 111/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2095 - val_loss: 0.0643 - learning_rate: 0.0010
# Epoch 112/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1514 - val_loss: 0.0767 - learning_rate: 0.0010
# Epoch 113/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1931 - val_loss: 0.0647 - learning_rate: 0.0010
# Epoch 114/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1975 - val_loss: 0.0679 - learning_rate: 0.0010
# Epoch 115/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1604 - val_loss: 0.0587 - learning_rate: 0.0010
# Epoch 116/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2463 - val_loss: 0.0700 - learning_rate: 0.0010
# Epoch 117/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1703 - val_loss: 0.0750 - learning_rate: 0.0010
# Epoch 118/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1551 - val_loss: 0.0557 - learning_rate: 0.0010
# Epoch 119/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1534 - val_loss: 0.0376 - learning_rate: 0.0010
# Epoch 120/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.1754 - val_loss: 0.0547 - learning_rate: 0.0010
# Epoch 121/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.1890 - val_loss: 0.0568 - learning_rate: 0.0010
# Epoch 122/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1496 - val_loss: 0.0391 - learning_rate: 0.0010
# Epoch 123/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1733 - val_loss: 0.0684 - learning_rate: 0.0010
# Epoch 124/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.1576 - val_loss: 0.0926 - learning_rate: 0.0010
# Epoch 125/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1575 - val_loss: 0.0880 - learning_rate: 0.0010
# Epoch 126/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1730 - val_loss: 0.0818 - learning_rate: 0.0010
# Epoch 127/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.3193 - val_loss: 0.0473 - learning_rate: 0.0010
# Epoch 128/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1480 - val_loss: 0.0564 - learning_rate: 0.0010
# Epoch 129/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1278 - val_loss: 0.0702 - learning_rate: 0.0010
# Epoch 130/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1378 - val_loss: 0.0661 - learning_rate: 1.0000e-04
# Epoch 131/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1562 - val_loss: 0.0616 - learning_rate: 1.0000e-04
# Epoch 132/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1539 - val_loss: 0.0593 - learning_rate: 1.0000e-04
# Epoch 133/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1210 - val_loss: 0.0572 - learning_rate: 1.0000e-04
# Epoch 134/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1488 - val_loss: 0.0540 - learning_rate: 1.0000e-04
# Epoch 135/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.1970 - val_loss: 0.0466 - learning_rate: 1.0000e-04
# Epoch 136/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.1217 - val_loss: 0.0436 - learning_rate: 1.0000e-04
# Epoch 137/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1319 - val_loss: 0.0436 - learning_rate: 1.0000e-04
# Epoch 138/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.1225 - val_loss: 0.0394 - learning_rate: 1.0000e-04
# Epoch 139/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1631 - val_loss: 0.0372 - learning_rate: 1.0000e-04
# Epoch 140/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.1585 - val_loss: 0.0346 - learning_rate: 1.0000e-04
# Epoch 141/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1692 - val_loss: 0.0379 - learning_rate: 1.0000e-04
# Epoch 142/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.1751 - val_loss: 0.0496 - learning_rate: 1.0000e-04
# Epoch 143/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.2695 - val_loss: 0.0614 - learning_rate: 1.0000e-04
# Epoch 144/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1536 - val_loss: 0.0539 - learning_rate: 1.0000e-04
# Epoch 145/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1486 - val_loss: 0.0504 - learning_rate: 1.0000e-04
# Epoch 146/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.1357 - val_loss: 0.0506 - learning_rate: 1.0000e-04
# Epoch 147/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1869 - val_loss: 0.0488 - learning_rate: 1.0000e-04
# Epoch 148/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.1457 - val_loss: 0.0411 - learning_rate: 1.0000e-04
# Epoch 149/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.1328 - val_loss: 0.0379 - learning_rate: 1.0000e-04
# Epoch 150/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1447 - val_loss: 0.0302 - learning_rate: 1.0000e-04
# Epoch 151/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0980 - val_loss: 0.0294 - learning_rate: 1.0000e-04
# Epoch 152/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1339 - val_loss: 0.0367 - learning_rate: 1.0000e-04
# Epoch 153/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1215 - val_loss: 0.0348 - learning_rate: 1.0000e-04
# Epoch 154/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.1421 - val_loss: 0.0391 - learning_rate: 1.0000e-04
# Epoch 155/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.1242 - val_loss: 0.0408 - learning_rate: 1.0000e-04
# Epoch 156/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.1397 - val_loss: 0.0396 - learning_rate: 1.0000e-04
# Epoch 157/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.1448 - val_loss: 0.0333 - learning_rate: 1.0000e-04
# Epoch 158/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1849 - val_loss: 0.0380 - learning_rate: 1.0000e-04
# Epoch 159/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1117 - val_loss: 0.0350 - learning_rate: 1.0000e-04
# Epoch 160/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1941 - val_loss: 0.0334 - learning_rate: 1.0000e-04
# Epoch 161/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1208 - val_loss: 0.0313 - learning_rate: 1.0000e-04
# Epoch 162/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1717 - val_loss: 0.0328 - learning_rate: 1.0000e-05
# Epoch 163/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.1792 - val_loss: 0.0286 - learning_rate: 1.0000e-05
# Epoch 164/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1561 - val_loss: 0.0295 - learning_rate: 1.0000e-05
# Epoch 165/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2156 - val_loss: 0.0395 - learning_rate: 1.0000e-05
# Epoch 166/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1516 - val_loss: 0.0382 - learning_rate: 1.0000e-05
# Epoch 167/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.1197 - val_loss: 0.0336 - learning_rate: 1.0000e-05
# Epoch 168/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1441 - val_loss: 0.0321 - learning_rate: 1.0000e-05
# Epoch 169/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1496 - val_loss: 0.0316 - learning_rate: 1.0000e-05
# Epoch 170/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1945 - val_loss: 0.0328 - learning_rate: 1.0000e-05
# Epoch 171/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1570 - val_loss: 0.0325 - learning_rate: 1.0000e-05
# Epoch 172/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1672 - val_loss: 0.0335 - learning_rate: 1.0000e-05
# Epoch 173/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1523 - val_loss: 0.0346 - learning_rate: 1.0000e-05
# Epoch 174/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1815 - val_loss: 0.0370 - learning_rate: 1.0000e-06
# Epoch 175/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1516 - val_loss: 0.0384 - learning_rate: 1.0000e-06
# Epoch 176/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1823 - val_loss: 0.0419 - learning_rate: 1.0000e-06
# Epoch 177/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.1701 - val_loss: 0.0364 - learning_rate: 1.0000e-06
# Epoch 178/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.1266 - val_loss: 0.0371 - learning_rate: 1.0000e-06
# Epoch 179/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1466 - val_loss: 0.0375 - learning_rate: 1.0000e-06
# Epoch 180/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1296 - val_loss: 0.0371 - learning_rate: 1.0000e-06
# Epoch 181/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1351 - val_loss: 0.0395 - learning_rate: 1.0000e-06
# Epoch 182/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1376 - val_loss: 0.0417 - learning_rate: 1.0000e-06
# Epoch 183/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.1617 - val_loss: 0.0394 - learning_rate: 1.0000e-06
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Train Loss: 0.02842843532562256
# Validation Loss: 0.030622189864516258
# Train MAE: 0.9081098562368985
# Validation MAE: 0.748870802110279

# %%
# Evaluate the model on the training set
train_loss = model.evaluate(X_train, y_train, verbose=0)
train_predictions = model.predict(X_train)
train_mae = np.mean(np.abs(train_predictions - y_train))
train_mse = np.mean((train_predictions - y_train)**2)
train_rmse = np.sqrt(train_mse)

# Evaluate the model on the validation set
val_loss = model.evaluate(X_val, y_val, verbose=0)
val_predictions = model.predict(X_val)
val_mae = np.mean(np.abs(val_predictions - y_val))
val_mse = np.mean((val_predictions - y_val)**2)
val_rmse = np.sqrt(val_mse)

print('Train Loss:', train_loss)
print('Train MAE:', train_mae)
print('Train MSE:', train_mse)
print('Train RMSE:', train_rmse)

print('Validation Loss:', val_loss)
print('Validation MAE:', val_mae)
print('Validation MSE:', val_mse)
print('Validation RMSE:', val_rmse)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Train Loss: 0.02842843532562256
# Train MAE: 0.9081098562368985
# Train MSE: 2.304293778407887
# Train RMSE: 1.517990045556257
# Validation Loss: 0.030622189864516258
# Validation MAE: 0.748870802110279
# Validation MSE: 1.5998305547056664
# Validation RMSE: 1.2648440831603183

# %% [markdown]
# ## **Forecasting**

# %%
import matplotlib.pyplot as plt

# Make predictions on the test data
predictions = model.predict(X_test)

# Inverse transform the predicted values
predictions_inv = scaler_y.inverse_transform(predictions.reshape(-1, 1)).flatten()

# Inverse transform the test labels for comparison
y_test_inv = scaler_y.inverse_transform(y_test.reshape(-1, 1)).flatten()

# Plot actual vs. predicted values
plt.figure(figsize=(10, 6))
plt.plot(salesmonthly_new['datum'][split_index:], y_test_inv, label='Actual')
plt.plot(salesmonthly_new['datum'][split_index:], predictions_inv, label='Predicted')
plt.title('Actual vs. Predicted Quantity')
plt.xlabel('Datum')
plt.ylabel('Quantity')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
# Number of future time steps to predict
future_steps = 30  # Adjust as needed

# Prepare the last window of data from the test set to predict future values
last_window = X_test[-1].reshape(1, -1)  # Reshape to match model input shape

# Predict future values iteratively
future_predictions = []
for _ in range(future_steps):
    # Predict the next value
    next_pred = model.predict(last_window)
    
    # Append the prediction to the list
    future_predictions.append(next_pred[0])
    
    # Update the last window by removing the first element and adding the prediction
    last_window = np.roll(last_window, -1)
    last_window[-1] = next_pred

# Inverse transform the predicted future values
future_predictions = scaler_y.inverse_transform(np.array(future_predictions).reshape(-1, 1)).flatten()

# Generate future dates for plotting
last_date = pd.to_datetime(salesmonthly_new['datum'].iloc[-1])
future_dates = [last_date + pd.DateOffset(months=i) for i in range(1, future_steps + 1)]

# Plot actual vs. predicted values with future predictions
plt.figure(figsize=(10, 6))
plt.plot(salesmonthly_new['datum'][split_index:], y_test_inv, label='Actual')
plt.plot(salesmonthly_new['datum'][split_index:], predictions_inv, label='Predicted')
plt.plot(future_dates, future_predictions, label='Future Predictions', linestyle='--')
plt.title('Actual vs. Predicted Quantity with Future Predictions')
plt.xlabel('Date')
plt.ylabel('Quantity')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %%
# Assuming your DataFrame is named df and the column containing quantities is named 'quantity'
highest_quantity_index = salesmonthly_new['Quantity'].idxmin()
highest_quantity_value = salesmonthly_new.loc[highest_quantity_index, 'Quantity']

print("Index of lowest quantity:", highest_quantity_index)
print("Lowest quantity:", highest_quantity_value)
# Out:
# Index of lowest quantity: 36
# Lowest quantity: 0.0

# %%
# Assuming your DataFrame is named df and the column containing quantities is named 'quantity'
highest_quantity_index = salesmonthly_new['Quantity'].idxmax()
highest_quantity_value = salesmonthly_new.loc[highest_quantity_index, 'Quantity']

print("Index of highest quantity:", highest_quantity_index)
print("Highest quantity:", highest_quantity_value)
# Out:
# Index of highest quantity: 219
# Highest quantity: 1856.8149999999996
